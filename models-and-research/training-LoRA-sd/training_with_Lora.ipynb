# %% [markdown]
# # Mask Generation #

# %%
# First, install PyTorch with CUDA support
# !pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu118

# Install required packages
# !pip install transformers
# !pip install opencv-python
# !pip install scipy
# !pip install setuptools==59.5.0
# !pip install pillow
# !pip install timm

# Install OneFormer specific dependencies
# !pip install -q git+https://github.com/cocodataset/panopticapi.git
# !pip install -q git+https://github.com/mcordts/cityscapesScripts.git
# !pip install -q pytorchvideo

# Optional: for better visualization
# !pip install matplotlib seaborn

# Verify CUDA is available
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")

# Import and verify transformers installation
from transformers import OneFormerProcessor, OneFormerForUniversalSegmentation

# Test model loading
processor = OneFormerProcessor.from_pretrained("shi-labs/oneformer_ade20k_swin_large")
model = OneFormerForUniversalSegmentation.from_pretrained("shi-labs/oneformer_ade20k_swin_large")

print("Setup completed successfully!")
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 34.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from scipy) (1.26.4)
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 46.8 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# arviz 0.20.0 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# Successfully installed setuptools-59.5.0
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.14)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm) (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm) (0.20.1+cu124)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm) (0.28.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm) (0.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm) (2025.1.31)
#   Preparing metadata (setup.py) ... done
#   Building wheel for panopticapi (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
#   Building wheel for cityscapesScripts (setup.py) ... done
#   Building wheel for typing (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 16.0 MB/s eta 0:00:00
#   Building wheel for pytorchvideo (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#   Building wheel for iopath (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# CUDA available: True
# CUDA device: Tesla T4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-317674273eb7> in <cell line: 0>()
#      25
#      26 # Import and verify transformers installation
# ---> 27 from transformers import OneFormerProcessor, OneFormerForUniversalSegmentation
#      28
#      29 # Test model loading
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1804         elif name in self._class_to_module.keys():
#    1805             module = self._get_module(self._class_to_module[name])
# -> 1806             value = getattr(module, name)
#    1807         elif name in self._modules:
#    1808             value = self._get_module(name)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1803             value = Placeholder
#    1804         elif name in self._class_to_module.keys():
# -> 1805             module = self._get_module(self._class_to_module[name])
#    1806             value = getattr(module, name)
#    1807         elif name in self._modules:
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1815     def _get_module(self, module_name: str):
#    1816         try:
# -> 1817             return importlib.import_module("." + module_name, self.__name__)
#    1818         except Exception as e:
#    1819             raise RuntimeError(
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/oneformer/modeling_oneformer.py in <module>
#      28 from ...activations import ACT2FN
#      29 from ...modeling_outputs import BaseModelOutput
# ---> 30 from ...modeling_utils import PreTrainedModel
#      31 from ...utils import (
#      32     ModelOutput,
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in <module>
#      49 from .integrations.flex_attention import flex_attention_forward
#      50 from .integrations.sdpa_attention import sdpa_attention_forward
# ---> 51 from .loss.loss_utils import LOSS_MAPPING
#      52 from .pytorch_utils import (  # noqa: F401
#      53     Conv1D,
#
# /usr/local/lib/python3.11/dist-packages/transformers/loss/loss_utils.py in <module>
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
#      18
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#      21 from .loss_rt_detr import RTDetrForObjectDetectionLoss
#
# /usr/local/lib/python3.11/dist-packages/transformers/loss/loss_deformable_detr.py in <module>
#       2 import torch.nn as nn
#       3
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#       6 from .loss_for_object_detection import (
#
# /usr/local/lib/python3.11/dist-packages/transformers/image_transforms.py in <module>
#      48
#      49 if is_tf_available():
# ---> 50     import tensorflow as tf
#      51
#      52 if is_flax_available():
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/__init__.py in <module>
#      47 _tf2.enable()
#      48
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/__internal__/__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/core/ag_ctx.py in <module>
#      19 import threading
#      20
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      23
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/utils/__init__.py in <module>
#      15 """Utility module that contains APIs usable in the generated code."""
#      16
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/utils/context_managers.py in <module>
#      17 import contextlib
#      18
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      21
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py in <module>
#      48 from tensorflow.python import tf2
#      49 from tensorflow.python.client import pywrap_tf_session
# ---> 50 from tensorflow.python.eager import context
#      51 from tensorflow.python.eager import core
#      52 from tensorflow.python.eager import monitoring
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in <module>
#      35 from tensorflow.python.client import pywrap_tf_session
#      36 from tensorflow.python.eager import cancellation
# ---> 37 from tensorflow.python.eager import execute
#      38 from tensorflow.python.eager import executor
#      39 from tensorflow.python.eager import monitoring
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in <module>
#      21 from tensorflow.python.framework import dtypes
#      22 from tensorflow.python.framework import tensor_conversion_registry
# ---> 23 from tensorflow.python.framework import tensor_shape
#      24 from tensorflow.python.types import core as core_types
#      25 from tensorflow.python.util import compat
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor_shape.py in <module>
#      24 from tensorflow.python.eager import monitoring
#      25 from tensorflow.python.platform import tf_logging as logging
# ---> 26 from tensorflow.python.saved_model import nested_structure_coder
#      27 from tensorflow.python.types import trace
#      28 from tensorflow.python.util.tf_export import tf_export
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/saved_model/nested_structure_coder.py in <module>
#      36 from tensorflow.python.types import internal
#      37 from tensorflow.python.util import compat
# ---> 38 from tensorflow.python.util import nest
#      39 from tensorflow.python.util.compat import collections_abc
#      40 from tensorflow.python.util.tf_export import tf_export
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/nest.py in <module>
#      93 from tensorflow.python.util import _pywrap_nest
#      94 from tensorflow.python.util import _pywrap_utils
# ---> 95 from tensorflow.python.util import nest_util
#      96 from tensorflow.python.util.tf_export import tf_export
#      97
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/nest_util.py in <module>
#      28 import enum
#      29
# ---> 30 import wrapt as _wrapt
#      31
#      32 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#
# /usr/local/lib/python3.11/dist-packages/wrapt/__init__.py in <module>
#      11 from .weakrefs import WeakFunctionProxy
#      12
# ---> 13 from .decorators import (adapter_factory, AdapterFactory, decorator,
#      14         synchronized)
#      15
#
# /usr/local/lib/python3.11/dist-packages/wrapt/decorators.py in <module>
#      35 from threading import Lock, RLock
#      36
# ---> 37 from .arguments import formatargspec
#      38
#      39 try:
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in module_from_spec(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _init_module_attrs(spec, module, override)
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
from PIL import Image
import torch
import matplotlib.pyplot as plt
from transformers import OneFormerProcessor, OneFormerForUniversalSegmentation

def process_image(image_path, core_mask_dir=None, overlay_output_dir=None):
  """Process a single image and generate segmentation masks using OneFormer"""
  processor = OneFormerProcessor.from_pretrained("shi-labs/oneformer_ade20k_swin_large")
  model = OneFormerForUniversalSegmentation.from_pretrained("shi-labs/oneformer_ade20k_swin_large")

  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  model = model.to(device)
  model.eval()

  image = Image.open(image_path).convert('RGB')
  print(f"Processing image: {image_path}")
  print(f"Image size: {image.size}")

  inputs = processor(images=image, task_inputs=["semantic"], return_tensors="pt")
  inputs = {k: v.to(device) if hasattr(v, "to") else v for k, v in inputs.items()}

  with torch.no_grad():
      outputs = model(**inputs)

  segmentation_maps = processor.post_process_semantic_segmentation(
      outputs,
      target_sizes=[(image.size[1], image.size[0])]
  )[0]

  segmentation = segmentation_maps.cpu().numpy()

  # Define background classes (architectural elements to exclude)
  background_classes = [0, 1, 3, 5, 4, 6, 8, 9, 14, 38]  # 0 is original background

  if overlay_output_dir:
    os.makedirs(overlay_output_dir, exist_ok=True)

  if core_mask_dir:
      os.makedirs(core_mask_dir, exist_ok=True)
      base_filename = os.path.splitext(os.path.basename(image_path))[0]

      # First, let's print all detected classes for debugging
      all_classes = np.unique(segmentation)
      id2label = model.config.id2label

      print("\nAll detected classes:")
      for class_id in all_classes:
          print(f"- Class {class_id}: {id2label[int(class_id)]}")

      # Create foreground mask - FIXED VERSION
      foreground_mask = np.ones_like(segmentation, dtype=np.uint8) * 255
      for bg_class in background_classes:  # <-- Changed to iterate over background_classes
          foreground_mask[segmentation == bg_class] = 0

      # Create masked segmentation
      masked_segmentation = segmentation.copy()
      masked_segmentation[foreground_mask == 0] = 0

      # Get unique classes in masked result
      unique_classes = np.unique(masked_segmentation)

      print("\nClasses in final mask (after excluding background elements):")
      for class_id in unique_classes:
          if class_id > 0:  # Skip 0 class
              print(f"- Class {class_id}: {id2label[int(class_id)]}")

      # Rest of visualization code remains the same
      num_classes = len(model.config.id2label)
      colors = []
      for i in range(num_classes):
          hue = i / num_classes
          colors.append(plt.cm.hsv(hue))
      colors = np.array(colors)

      colored_segmentation = colors[masked_segmentation]
      original_image = np.array(image).astype(float) / 255
      overlay = 0.6 * original_image + 0.4 * colored_segmentation[:,:,:3]

      plt.figure(figsize=(20, 20))
      plt.imshow(overlay)

      from scipy import ndimage

      for class_id in unique_classes:
          if class_id > 0:  # Skip 0 class
              mask = masked_segmentation == class_id
              if mask.any():
                  labeled_mask, num_features = ndimage.label(mask)
                  for label_idx in range(1, num_features + 1):
                      component_mask = labeled_mask == label_idx
                      cy, cx = ndimage.center_of_mass(component_mask)
                      plt.text(cx, cy, id2label[int(class_id)],
                              color='black',
                              bbox=dict(facecolor='white', alpha=0.7),
                              ha='center',
                              va='center',
                              fontsize=12)

      plt.axis('off')

      overlay_path = os.path.join(overlay_output_dir, f"{base_filename}_overlay_labeled.png")
      plt.savefig(overlay_path, bbox_inches='tight', pad_inches=0)
      plt.close()
      print(f"Saved labeled overlay to: {overlay_path}")

      mask_path = os.path.join(core_mask_dir, f"{base_filename}_foreground_mask.png")
      Image.fromarray(foreground_mask).save(mask_path)
      print(f"Saved mask to: {mask_path}")

  return segmentation

def main():
    # Define paths
    input_dir = "/content/objects/"
    core_mask_dir = "/content/core_masks"
    overlay_output_dir = "/content/overlay_images"

    # Create output directory
    os.makedirs(core_mask_dir, exist_ok=True)
    os.makedirs(overlay_output_dir, exist_ok=True)

    # Get list of images
    valid_extensions = ('.png', '.jpg', '.jpeg', '.tiff', '.bmp')
    image_files = [
        f for f in os.listdir(input_dir)
        if os.path.isfile(os.path.join(input_dir, f))
        and f.lower().endswith(valid_extensions)
    ]

    if not image_files:
        print(f"No image files found in {input_dir}")
        return

    print(f"Found {len(image_files)} images to process")

    # Process each image
    for idx, image_file in enumerate(image_files, 1):
        print(f"\nProcessing image {idx}/{len(image_files)}")
        image_path = os.path.join(input_dir, image_file)

        try:
            process_image(image_path=image_path, core_mask_dir=core_mask_dir, overlay_output_dir=overlay_output_dir)
            print(f"Successfully processed {image_file}")
        except Exception as e:
            print(f"Error processing {image_file}: {str(e)}")
            import traceback
            traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# Found 2 images to process
#
# Processing image 1/2
# /usr/local/lib/python3.11/dist-packages/transformers/utils/deprecation.py:165: UserWarning: The following named arguments are not valid for `OneFormerImageProcessor.__init__` and were ignored: '_max_size'
#   return func(*args, **kwargs)
# Processing image: /content/objects/595043039.png
# Image size: (1500, 1000)
#
# All detected classes:
# - Class 0: wall
# - Class 3: floor
# - Class 5: ceiling
# - Class 7: bed
# - Class 8: window
# - Class 15: table
# - Class 19: chair
# - Class 36: lamp
# - Class 39: cushion
# - Class 57: pillow
# - Class 64: coffee table
# - Class 148: clock
#
# Classes in final mask (after excluding background elements):
# - Class 7: bed
# - Class 15: table
# - Class 19: chair
# - Class 36: lamp
# - Class 39: cushion
# - Class 57: pillow
# - Class 64: coffee table
# - Class 148: clock
# Saved labeled overlay to: /content/overlay_images/595043039_overlay_labeled.png
# Saved mask to: /content/core_masks/595043039_foreground_mask.png
# Successfully processed 595043039.png
#
# Processing image 2/2
# Processing image: /content/objects/903254896.png
# Image size: (1500, 1000)
#
# All detected classes:
# - Class 0: wall
# - Class 3: floor
# - Class 5: ceiling
# - Class 7: bed
# - Class 8: window
# - Class 10: cabinet
# - Class 14: door
# - Class 17: plant
# - Class 22: painting, picture
# - Class 23: sofa
# - Class 36: lamp
# - Class 38: rail
# - Class 63: blind, screen
# - Class 82: light
# - Class 125: pot
#
# Classes in final mask (after excluding background elements):
# - Class 7: bed
# - Class 10: cabinet
# - Class 17: plant
# - Class 22: painting, picture
# - Class 23: sofa
# - Class 36: lamp
# - Class 63: blind, screen
# - Class 82: light
# - Class 125: pot
# Saved labeled overlay to: /content/overlay_images/903254896_overlay_labeled.png
# Saved mask to: /content/core_masks/903254896_foreground_mask.png
# Successfully processed 903254896.png

# %%
import os
import numpy as np
import cv2
from PIL import Image
import torch
import matplotlib.pyplot as plt
from transformers import OneFormerProcessor, OneFormerForUniversalSegmentation
from google.colab import drive
drive.mount('/content/drive')

def process_image(image_path, core_mask_dir=None, overlay_output_dir=None, margin_mask_dir=None, margin_size=40):
    """Process a single image and generate segmentation masks using OneFormer"""
    processor = OneFormerProcessor.from_pretrained("shi-labs/oneformer_ade20k_swin_large")
    model = OneFormerForUniversalSegmentation.from_pretrained("shi-labs/oneformer_ade20k_swin_large")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()

    image = Image.open(image_path).convert('RGB')
    image_np = np.array(image)  # Convert to NumPy array for processing

    print(f"Processing image: {image_path}")
    print(f"Image size: {image.size}")

    inputs = processor(images=image, task_inputs=["semantic"], return_tensors="pt")
    inputs = {k: v.to(device) if hasattr(v, "to") else v for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model(**inputs)

    segmentation_maps = processor.post_process_semantic_segmentation(
        outputs,
        target_sizes=[(image.size[1], image.size[0])]
    )[0]

    segmentation = segmentation_maps.cpu().numpy()

    # Define background classes (architectural elements to exclude)
    background_classes = [0, 1, 3, 5, 4, 6, 8, 9, 14, 38]

    if core_mask_dir:
        os.makedirs(core_mask_dir, exist_ok=True)
    if overlay_output_dir:
        os.makedirs(overlay_output_dir, exist_ok=True)
    if margin_mask_dir:
        os.makedirs(margin_mask_dir, exist_ok=True)

    base_filename = os.path.splitext(os.path.basename(image_path))[0]

    # Create foreground mask
    foreground_mask = np.ones_like(segmentation, dtype=np.uint8) * 255
    for bg_class in background_classes:
        foreground_mask[segmentation == bg_class] = 0

    # Save foreground mask
    mask_path = os.path.join(core_mask_dir, f"{base_filename}_foreground_mask.png")
    Image.fromarray(foreground_mask).save(mask_path)
    print(f"Saved mask to: {mask_path}")

    # Generate margin mask
    kernel = np.ones((margin_size, margin_size), np.uint8)
    dilated_mask = cv2.dilate(foreground_mask, kernel, iterations=1)
    margin_mask = dilated_mask - foreground_mask

    # Create RGBA margin mask (copy real pixels with transparency)
    margin_rgba = np.zeros((*image_np.shape[:2], 4), dtype=np.uint8)
    margin_rgba[:, :, :3] = image_np  # Copy RGB channels
    margin_rgba[:, :, 3] = (margin_mask > 0) * 128  # Set alpha to 128 for the margin

    # Save margin mask
    margin_mask_path = os.path.join(margin_mask_dir, f"{base_filename}_margin_mask.png")
    Image.fromarray(margin_rgba).save(margin_mask_path)
    print(f"Saved margin mask to: {margin_mask_path}")

    return segmentation

def main():
    # Define paths
    # input_dir = "/content/objects/"
    # core_mask_dir = "/content/core_masks"
    # overlay_output_dir = "/content/overlay_images"
    # margin_mask_dir = "/content/margin_masks"  # New directory for margin masks

    # Define paths for input and output directories
    input_dir = "/content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed"
    core_mask_dir = "/content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks"
    margin_mask_dir = "/content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks"
    overlay_output_dir = "/content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMaskOverlays"

    # Create output directories
    os.makedirs(core_mask_dir, exist_ok=True)
    os.makedirs(overlay_output_dir, exist_ok=True)
    os.makedirs(margin_mask_dir, exist_ok=True)

    # Get list of images
    valid_extensions = ('.png', '.jpg', '.jpeg', '.tiff', '.bmp')
    image_files = [
        f for f in os.listdir(input_dir)
        if os.path.isfile(os.path.join(input_dir, f))
        and f.lower().endswith(valid_extensions)
    ]

    if not image_files:
        print(f"No image files found in {input_dir}")
        return

    print(f"Found {len(image_files)} images to process")

    # Process each image
    for idx, image_file in enumerate(image_files, 1):
        print(f"\nProcessing image {idx}/{len(image_files)}")
        image_path = os.path.join(input_dir, image_file)

        try:
            process_image(image_path=image_path,
                          core_mask_dir=core_mask_dir,
                          overlay_output_dir=overlay_output_dir,
                          margin_mask_dir=margin_mask_dir)
            print(f"Successfully processed {image_file}")
        except Exception as e:
            print(f"Error processing {image_file}: {str(e)}")
            import traceback
            traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 323 images to process
#
# Processing image 1/323
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/deprecation.py:165: UserWarning: The following named arguments are not valid for `OneFormerImageProcessor.__init__` and were ignored: '_max_size'
#   return func(*args, **kwargs)
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1011640917.png
# Image size: (1500, 2000)
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1011640917_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1011640917_margin_mask.png
# Successfully processed 1011640917.png
#
# Processing image 2/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1011640934.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1011640934_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1011640934_margin_mask.png
# Successfully processed 1011640934.png
#
# Processing image 3/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1033248940.png
# Image size: (1500, 2670)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1033248940_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1033248940_margin_mask.png
# Successfully processed 1033248940.png
#
# Processing image 4/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1088613596.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1088613596_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1088613596_margin_mask.png
# Successfully processed 1088613596.png
#
# Processing image 5/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1011640936.png
# Image size: (1500, 2000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1011640936_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1011640936_margin_mask.png
# Successfully processed 1011640936.png
#
# Processing image 6/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1033248934.png
# Image size: (1500, 2672)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1033248934_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1033248934_margin_mask.png
# Successfully processed 1033248934.png
#
# Processing image 7/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1099074215.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1099074215_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1099074215_margin_mask.png
# Successfully processed 1099074215.png
#
# Processing image 8/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1088613598.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1088613598_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1088613598_margin_mask.png
# Successfully processed 1088613598.png
#
# Processing image 9/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1099074216.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1099074216_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1099074216_margin_mask.png
# Successfully processed 1099074216.png
#
# Processing image 10/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1181094618.png
# Image size: (1500, 994)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1181094618_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1181094618_margin_mask.png
# Successfully processed 1181094618.png
#
# Processing image 11/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1147918260.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1147918260_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1147918260_margin_mask.png
# Successfully processed 1147918260.png
#
# Processing image 12/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1181094642.png
# Image size: (1500, 994)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1181094642_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1181094642_margin_mask.png
# Successfully processed 1181094642.png
#
# Processing image 13/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1147918291.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1147918291_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1147918291_margin_mask.png
# Successfully processed 1147918291.png
#
# Processing image 14/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1191928055.png
# Image size: (1500, 1129)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1191928055_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1191928055_margin_mask.png
# Successfully processed 1191928055.png
#
# Processing image 15/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1183424555.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1183424555_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1183424555_margin_mask.png
# Successfully processed 1183424555.png
#
# Processing image 16/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1202799141.png
# Image size: (1500, 2000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1202799141_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1202799141_margin_mask.png
# Successfully processed 1202799141.png
#
# Processing image 17/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1181094661.png
# Image size: (1500, 2264)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1181094661_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1181094661_margin_mask.png
# Successfully processed 1181094661.png
#
# Processing image 18/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1191928052.png
# Image size: (1500, 1129)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1191928052_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1191928052_margin_mask.png
# Successfully processed 1191928052.png
#
# Processing image 19/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1183424573.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1183424573_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1183424573_margin_mask.png
# Successfully processed 1183424573.png
#
# Processing image 20/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1183424551.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1183424551_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1183424551_margin_mask.png
# Successfully processed 1183424551.png
#
# Processing image 21/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1227808279.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1227808279_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1227808279_margin_mask.png
# Successfully processed 1227808279.png
#
# Processing image 22/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1227808326.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1227808326_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1227808326_margin_mask.png
# Successfully processed 1227808326.png
#
# Processing image 23/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1227808295.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1227808295_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1227808295_margin_mask.png
# Successfully processed 1227808295.png
#
# Processing image 24/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1203464596.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1203464596_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1203464596_margin_mask.png
# Successfully processed 1203464596.png
#
# Processing image 25/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1203464595.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1203464595_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1203464595_margin_mask.png
# Successfully processed 1203464595.png
#
# Processing image 26/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1227808259.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1227808259_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1227808259_margin_mask.png
# Successfully processed 1227808259.png
#
# Processing image 27/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1222626305.png
# Image size: (1500, 844)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1222626305_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1222626305_margin_mask.png
# Successfully processed 1222626305.png
#
# Processing image 28/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1246967864.png
# Image size: (1500, 2000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1246967864_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1246967864_margin_mask.png
# Successfully processed 1246967864.png
#
# Processing image 29/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1242910304.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1242910304_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1242910304_margin_mask.png
# Successfully processed 1242910304.png
#
# Processing image 30/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1264103457.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1264103457_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1264103457_margin_mask.png
# Successfully processed 1264103457.png
#
# Processing image 31/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1246967806.png
# Image size: (1500, 2000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1246967806_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1246967806_margin_mask.png
# Successfully processed 1246967806.png
#
# Processing image 32/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1231610707.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1231610707_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1231610707_margin_mask.png
# Successfully processed 1231610707.png
#
# Processing image 33/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1264103486.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1264103486_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1264103486_margin_mask.png
# Successfully processed 1264103486.png
#
# Processing image 34/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1287145876.png
# Image size: (1500, 999)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1287145876_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1287145876_margin_mask.png
# Successfully processed 1287145876.png
#
# Processing image 35/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1287123450.png
# Image size: (1500, 999)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1287123450_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1287123450_margin_mask.png
# Successfully processed 1287123450.png
#
# Processing image 36/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1287123476.png
# Image size: (1500, 999)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1287123476_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1287123476_margin_mask.png
# Successfully processed 1287123476.png
#
# Processing image 37/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1284991539.png
# Image size: (1500, 1124)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1284991539_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1284991539_margin_mask.png
# Successfully processed 1284991539.png
#
# Processing image 38/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1284991537.png
# Image size: (1500, 1980)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1284991537_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1284991537_margin_mask.png
# Successfully processed 1284991537.png
#
# Processing image 39/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1289161788.png
# Image size: (1500, 960)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1289161788_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1289161788_margin_mask.png
# Successfully processed 1289161788.png
#
# Processing image 40/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1291025298.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1291025298_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1291025298_margin_mask.png
# Successfully processed 1291025298.png
#
# Processing image 41/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299251715.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299251715_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299251715_margin_mask.png
# Successfully processed 1299251715.png
#
# Processing image 42/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1296149109.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1296149109_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1296149109_margin_mask.png
# Successfully processed 1296149109.png
#
# Processing image 43/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1294830298.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1294830298_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1294830298_margin_mask.png
# Successfully processed 1294830298.png
#
# Processing image 44/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1296149134.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1296149134_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1296149134_margin_mask.png
# Successfully processed 1296149134.png
#
# Processing image 45/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1297455813.png
# Image size: (1500, 1001)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1297455813_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1297455813_margin_mask.png
# Successfully processed 1297455813.png
#
# Processing image 46/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1294830308.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1294830308_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1294830308_margin_mask.png
# Successfully processed 1294830308.png
#
# Processing image 47/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1297162632.png
# Image size: (1500, 1001)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1297162632_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1297162632_margin_mask.png
# Successfully processed 1297162632.png
#
# Processing image 48/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1297455804.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1297455804_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1297455804_margin_mask.png
# Successfully processed 1297455804.png
#
# Processing image 49/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299217122.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299217122_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299217122_margin_mask.png
# Successfully processed 1299217122.png
#
# Processing image 50/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299251817.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299251817_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299251817_margin_mask.png
# Successfully processed 1299251817.png
#
# Processing image 51/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299282983.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299282983_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299282983_margin_mask.png
# Successfully processed 1299282983.png
#
# Processing image 52/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299470242.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299470242_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299470242_margin_mask.png
# Successfully processed 1299470242.png
#
# Processing image 53/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299439117.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299439117_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299439117_margin_mask.png
# Successfully processed 1299439117.png
#
# Processing image 54/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299300436.png
# Image size: (1500, 891)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299300436_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299300436_margin_mask.png
# Successfully processed 1299300436.png
#
# Processing image 55/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299300438.png
# Image size: (1500, 891)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299300438_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299300438_margin_mask.png
# Successfully processed 1299300438.png
#
# Processing image 56/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299439124.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299439124_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299439124_margin_mask.png
# Successfully processed 1299439124.png
#
# Processing image 57/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299300425.png
# Image size: (600, 356)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299300425_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299300425_margin_mask.png
# Successfully processed 1299300425.png
#
# Processing image 58/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299490880.png
# Image size: (1500, 2002)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299490880_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299490880_margin_mask.png
# Successfully processed 1299490880.png
#
# Processing image 59/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299470302.png
# Image size: (1500, 2002)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299470302_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299470302_margin_mask.png
# Successfully processed 1299470302.png
#
# Processing image 60/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299490902.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299490902_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299490902_margin_mask.png
# Successfully processed 1299490902.png
#
# Processing image 61/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299490927.png
# Image size: (600, 450)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299490927_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299490927_margin_mask.png
# Successfully processed 1299490927.png
#
# Processing image 62/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299470295.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299470295_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299470295_margin_mask.png
# Successfully processed 1299470295.png
#
# Processing image 63/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299603434.png
# Image size: (1500, 1001)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299603434_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299603434_margin_mask.png
# Successfully processed 1299603434.png
#
# Processing image 64/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299603435.png
# Image size: (1500, 999)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299603435_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299603435_margin_mask.png
# Successfully processed 1299603435.png
#
# Processing image 65/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299600750.png
# Image size: (1500, 844)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299600750_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299600750_margin_mask.png
# Successfully processed 1299600750.png
#
# Processing image 66/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299612178.png
# Image size: (1500, 2000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299612178_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299612178_margin_mask.png
# Successfully processed 1299612178.png
#
# Processing image 67/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299600690.png
# Image size: (1500, 844)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299600690_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299600690_margin_mask.png
# Successfully processed 1299600690.png
#
# Processing image 68/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299617024.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299617024_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299617024_margin_mask.png
# Successfully processed 1299617024.png
#
# Processing image 69/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299653221.png
# Image size: (1500, 999)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299653221_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299653221_margin_mask.png
# Successfully processed 1299653221.png
#
# Processing image 70/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299619797.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299619797_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299619797_margin_mask.png
# Successfully processed 1299619797.png
#
# Processing image 71/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299653295.png
# Image size: (600, 400)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299653295_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299653295_margin_mask.png
# Successfully processed 1299653295.png
#
# Processing image 72/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299619751.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299619751_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299619751_margin_mask.png
# Successfully processed 1299619751.png
#
# Processing image 73/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299653197.png
# Image size: (1500, 999)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299653197_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299653197_margin_mask.png
# Successfully processed 1299653197.png
#
# Processing image 74/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299618381.png
# Image size: (1500, 1002)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299618381_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299618381_margin_mask.png
# Successfully processed 1299618381.png
#
# Processing image 75/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299618497.png
# Image size: (1500, 1002)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299618497_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299618497_margin_mask.png
# Successfully processed 1299618497.png
#
# Processing image 76/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299653172.png
# Image size: (1500, 999)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299653172_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299653172_margin_mask.png
# Successfully processed 1299653172.png
#
# Processing image 77/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299670425.png
# Image size: (600, 450)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299670425_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299670425_margin_mask.png
# Successfully processed 1299670425.png
#
# Processing image 78/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299669847.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299669847_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299669847_margin_mask.png
# Successfully processed 1299669847.png
#
# Processing image 79/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299658818.png
# Image size: (1500, 844)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299658818_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299658818_margin_mask.png
# Successfully processed 1299658818.png
#
# Processing image 80/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299655481.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299655481_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299655481_margin_mask.png
# Successfully processed 1299655481.png
#
# Processing image 81/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299670430.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299670430_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299670430_margin_mask.png
# Successfully processed 1299670430.png
#
# Processing image 82/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299672983.png
# Image size: (600, 450)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299672983_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299672983_margin_mask.png
# Successfully processed 1299672983.png
#
# Processing image 83/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299672991.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299672991_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299672991_margin_mask.png
# Successfully processed 1299672991.png
#
# Processing image 84/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299655670.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299655670_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299655670_margin_mask.png
# Successfully processed 1299655670.png
#
# Processing image 85/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299660389.png
# Image size: (1500, 1111)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299660389_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299660389_margin_mask.png
# Successfully processed 1299660389.png
#
# Processing image 86/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299696719.png
# Image size: (1500, 843)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299696719_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299696719_margin_mask.png
# Successfully processed 1299696719.png
#
# Processing image 87/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299736726.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299736726_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299736726_margin_mask.png
# Successfully processed 1299736726.png
#
# Processing image 88/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299673223.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299673223_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299673223_margin_mask.png
# Successfully processed 1299673223.png
#
# Processing image 89/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299736701.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299736701_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299736701_margin_mask.png
# Successfully processed 1299736701.png
#
# Processing image 90/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299696696.png
# Image size: (1500, 843)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299696696_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299696696_margin_mask.png
# Successfully processed 1299696696.png
#
# Processing image 91/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299736860.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299736860_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299736860_margin_mask.png
# Successfully processed 1299736860.png
#
# Processing image 92/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299746361.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299746361_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299746361_margin_mask.png
# Successfully processed 1299746361.png
#
# Processing image 93/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299746320.png
# Image size: (600, 400)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299746320_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299746320_margin_mask.png
# Successfully processed 1299746320.png
#
# Processing image 94/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299746351.png
# Image size: (1500, 1001)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299746351_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299746351_margin_mask.png
# Successfully processed 1299746351.png
#
# Processing image 95/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299736829.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299736829_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299736829_margin_mask.png
# Successfully processed 1299736829.png
#
# Processing image 96/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299736865.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299736865_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299736865_margin_mask.png
# Successfully processed 1299736865.png
#
# Processing image 97/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299756658.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299756658_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299756658_margin_mask.png
# Successfully processed 1299756658.png
#
# Processing image 98/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299756566.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299756566_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299756566_margin_mask.png
# Successfully processed 1299756566.png
#
# Processing image 99/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299746379.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299746379_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299746379_margin_mask.png
# Successfully processed 1299746379.png
#
# Processing image 100/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299772172.png
# Image size: (1500, 2000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299772172_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299772172_margin_mask.png
# Successfully processed 1299772172.png
#
# Processing image 101/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299778158.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299778158_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299778158_margin_mask.png
# Successfully processed 1299778158.png
#
# Processing image 102/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299774182.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299774182_foreground_mask.png
# ...
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299952656_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299952656_margin_mask.png
# Successfully processed 1299952656.png
#
# Processing image 290/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299949295.png
# Image size: (1500, 1130)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299949295_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299949295_margin_mask.png
# Successfully processed 1299949295.png
#
# Processing image 291/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299945690.png
# Image size: (1500, 971)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299945690_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299945690_margin_mask.png
# Successfully processed 1299945690.png
#
# Processing image 292/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299918059.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299918059_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299918059_margin_mask.png
# Successfully processed 1299918059.png
#
# Processing image 293/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299939175.png
# Image size: (1500, 995)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299939175_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299939175_margin_mask.png
# Successfully processed 1299939175.png
#
# Processing image 294/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299939179.png
# Image size: (1500, 995)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299939179_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299939179_margin_mask.png
# Successfully processed 1299939179.png
#
# Processing image 295/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299953974.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299953974_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299953974_margin_mask.png
# Successfully processed 1299953974.png
#
# Processing image 296/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299960017.png
# Image size: (600, 400)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299960017_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299960017_margin_mask.png
# Successfully processed 1299960017.png
#
# Processing image 297/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299961850.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299961850_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299961850_margin_mask.png
# Successfully processed 1299961850.png
#
# Processing image 298/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299953939.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299953939_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299953939_margin_mask.png
# Successfully processed 1299953939.png
#
# Processing image 299/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299963326.png
# Image size: (1500, 1101)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299963326_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299963326_margin_mask.png
# Successfully processed 1299963326.png
#
# Processing image 300/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299953937.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299953937_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299953937_margin_mask.png
# Successfully processed 1299953937.png
#
# Processing image 301/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299953995.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299953995_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299953995_margin_mask.png
# Successfully processed 1299953995.png
#
# Processing image 302/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299963327.png
# Image size: (1500, 1134)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299963327_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299963327_margin_mask.png
# Successfully processed 1299963327.png
#
# Processing image 303/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299975353.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299975353_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299975353_margin_mask.png
# Successfully processed 1299975353.png
#
# Processing image 304/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299963911.png
# Image size: (1500, 2000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299963911_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299963911_margin_mask.png
# Successfully processed 1299963911.png
#
# Processing image 305/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299975329.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299975329_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299975329_margin_mask.png
# Successfully processed 1299975329.png
#
# Processing image 306/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299963348.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299963348_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299963348_margin_mask.png
# Successfully processed 1299963348.png
#
# Processing image 307/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299999270.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299999270_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299999270_margin_mask.png
# Successfully processed 1299999270.png
#
# Processing image 308/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299980577.png
# Image size: (1500, 2000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299980577_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299980577_margin_mask.png
# Successfully processed 1299980577.png
#
# Processing image 309/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299998591.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299998591_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299998591_margin_mask.png
# Successfully processed 1299998591.png
#
# Processing image 310/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299999328.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299999328_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299999328_margin_mask.png
# Successfully processed 1299999328.png
#
# Processing image 311/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299999327.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299999327_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299999327_margin_mask.png
# Successfully processed 1299999327.png
#
# Processing image 312/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/700125260.png
# Image size: (1500, 1127)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/700125260_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/700125260_margin_mask.png
# Successfully processed 700125260.png
#
# Processing image 313/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/773740909.png
# Image size: (1500, 998)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/773740909_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/773740909_margin_mask.png
# Successfully processed 773740909.png
#
# Processing image 314/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299999434.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299999434_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299999434_margin_mask.png
# Successfully processed 1299999434.png
#
# Processing image 315/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/595043039.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/595043039_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/595043039_margin_mask.png
# Successfully processed 595043039.png
#
# Processing image 316/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/773740910.png
# Image size: (1500, 998)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/773740910_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/773740910_margin_mask.png
# Successfully processed 773740910.png
#
# Processing image 317/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/773740891.png
# Image size: (1500, 998)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/773740891_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/773740891_margin_mask.png
# Successfully processed 773740891.png
#
# Processing image 318/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/1299999428.png
# Image size: (1500, 1125)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/1299999428_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/1299999428_margin_mask.png
# Successfully processed 1299999428.png
#
# Processing image 319/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/905212054.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/905212054_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/905212054_margin_mask.png
# Successfully processed 905212054.png
#
# Processing image 320/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/773810658.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/773810658_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/773810658_margin_mask.png
# Successfully processed 773810658.png
#
# Processing image 321/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/905212034.png
# Image size: (1500, 1124)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/905212034_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/905212034_margin_mask.png
# Successfully processed 905212034.png
#
# Processing image 322/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/903254896.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/903254896_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/903254896_margin_mask.png
# Successfully processed 903254896.png
#
# Processing image 323/323
# Processing image: /content/drive/My Drive/Colab Notebooks/DATASETS/PhotosWithObjects/Uncompressed/903254897.png
# Image size: (1500, 1000)
# Saved mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedCoreMasks/903254897_foreground_mask.png
# Saved margin mask to: /content/drive/My Drive/Colab Notebooks/DATASETS/AutomaticallyGeneratedMarginMasks/903254897_margin_mask.png
# Successfully processed 903254897.png

# %% [markdown]
# # Finetuning #

# %%
# !git clone https://github.com/lsunol/casalimpia.git
# Out:
# Cloning into 'casalimpia'...
# remote: Enumerating objects: 13781, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 13781 (delta 73), reused 106 (delta 33), pack-reused 13619 (from 2)
# Receiving objects: 100% (13781/13781), 2.39 GiB | 27.57 MiB/s, done.
# Resolving deltas: 100% (298/298), done.

# %%
# !pip install -r /content/casalimpia/back/requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 1)) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 4)) (0.21.0+cu124)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 5)) (0.32.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 6)) (1.14.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 7)) (0.25.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 8)) (4.48.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 9)) (4.67.1)
# Collecting torchmetrics (from -r /content/casalimpia/back/requirements.txt (line 10))
#   Downloading torchmetrics-1.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from -r /content/casalimpia/back/requirements.txt (line 11)) (0.19.8)
# Collecting lpips (from -r /content/casalimpia/back/requirements.txt (line 12))
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r /content/casalimpia/back/requirements.txt (line 1))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/casalimpia/back/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r /content/casalimpia/back/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft->-r /content/casalimpia/back/requirements.txt (line 3)) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft->-r /content/casalimpia/back/requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft->-r /content/casalimpia/back/requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft->-r /content/casalimpia/back/requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft->-r /content/casalimpia/back/requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: huggingface-hub>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from peft->-r /content/casalimpia/back/requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->-r /content/casalimpia/back/requirements.txt (line 4)) (11.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers->-r /content/casalimpia/back/requirements.txt (line 5)) (8.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers->-r /content/casalimpia/back/requirements.txt (line 5)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers->-r /content/casalimpia/back/requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r /content/casalimpia/back/requirements.txt (line 7)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r /content/casalimpia/back/requirements.txt (line 7)) (2025.2.18)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r /content/casalimpia/back/requirements.txt (line 7)) (0.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /content/casalimpia/back/requirements.txt (line 8)) (0.21.1)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics->-r /content/casalimpia/back/requirements.txt (line 10))
#   Downloading lightning_utilities-0.14.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (4.25.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (2.10.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (2.22.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (75.1.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers->-r /content/casalimpia/back/requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers->-r /content/casalimpia/back/requirements.txt (line 5)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers->-r /content/casalimpia/back/requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers->-r /content/casalimpia/back/requirements.txt (line 5)) (2025.1.31)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers->-r /content/casalimpia/back/requirements.txt (line 5)) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r /content/casalimpia/back/requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r /content/casalimpia/back/requirements.txt (line 11)) (5.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.5 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.3-py3-none-any.whl (931 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.7/931.7 kB 43.2 MB/s eta 0:00:00
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 4.7 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.1-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, lpips
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-utilities-0.14.1 lpips-0.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchmetrics-1.6.3

# %%
##upload code with changes here
##and change single mask dataset and mask if necessary
# !pip install accelerate
# !pip install prodigyopt
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.3.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Collecting prodigyopt
#   Downloading prodigyopt-1.1.2-py3-none-any.whl.metadata (4.8 kB)
# Downloading prodigyopt-1.1.2-py3-none-any.whl (10 kB)
# Installing collected packages: prodigyopt
# Successfully installed prodigyopt-1.1.2

# %%
# !sed -i 's|inputs_dir="./back/data/singleImageDataset/emptyRoom"|inputs_dir="./data/singleImageDataset/emptyRoom"|' /content/casalimpia/back/empty_rooms_dataset.py
# !sed -i 's|masks_dir="./back/data/singleImageDataset/emptyMask"|masks_dir="./data/singleImageDataset/emptyMask"|' /content/casalimpia/back/empty_rooms_dataset.py

# Create a new cell and run this command to fix the paths
# !sed -i 's|"./back/data/singleImageDataset/emptyRoom"|"./data/singleImageDataset/emptyRoom"|' /content/casalimpia/back/empty_rooms_dataset.py
# !sed -i 's|"./back/data/singleImageDataset/emptyMask"|"./data/singleImageDataset/emptyMask"|' /content/casalimpia/back/empty_rooms_dataset.py

# %%
##without margin mask
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/casalimpia/back

# !python /content/casalimpia/back/main.py \
--empty-rooms-dir '/content/drive/My Drive/DATASETS/EmptyRooms/unique_unwatermarked' \
--masks-dir '/content/drive/My Drive/DATASETS/AutomaticallyGeneratedCoreMasks' \
--output-dir '/content/casalimpia/back/data' \
--model 'stability-ai' \
--epochs 15 \
--batch-size 10 \
--initial-learning-rate 1e-3 \
--img-size 512 \
--lora-rank 16 \
--lora-alpha 8 \
--lora-dropout 0.1 \
--lora-target-modules to_k to_q to_v to_out.0 \
--img-size 512 \
--lr-scheduler 'cosine' \
--dtype 'float32' \
--save-latent-representations
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/casalimpia/back
# 2025-03-03 20:24:11.527872: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-03 20:24:11.546568: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741033451.569177   20261 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741033451.575959   20261 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 20:24:11.599038: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Flash attention and related optimizations are ENABLED.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ferranmartiol (ferranmartiol-gfdgfd) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.7
# wandb: Run data is saved locally in /content/casalimpia/back/wandb/run-20250303_202416-gom17xko
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing
#  25% 225/902 [31:22<1:32:17,  8.18s/it]2025-03-03 20:55:55 - INFO - Batch loss: 0.10522077232599258 | Learning rate: 0.0009998861270380255
#  25% 226/902 [31:38<1:34:40,  8.40s/it]
# Traceback (most recent call last):
#   File "/content/casalimpia/back/main.py", line 554, in <module>
#     main()
#   File "/content/casalimpia/back/main.py", line 525, in main
#     train_lora(model_id,
#   File "/content/casalimpia/back/main.py", line 272, in train_lora
#     for step, (input_images, input_masks, targets, unpadded_masks) in enumerate(tqdm(train_loader)):
#   File "/usr/local/lib/python3.11/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.11/dist-packages/accelerate/data_loader.py", line 574, in __iter__
#     next_batch = next(dataloader_iter)
#                  ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 701, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 757, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py", line 50, in fetch
#     data = self.dataset.__getitems__(possibly_batched_index)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataset.py", line 420, in __getitems__
#     return [self.dataset[self.indices[idx]] for idx in indices]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataset.py", line 420, in <listcomp>
#     return [self.dataset[self.indices[idx]] for idx in indices]
#             ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/content/casalimpia/back/empty_rooms_dataset.py", line 52, in __getitem__
#     input_image = Image.open(input_path).convert("RGB")
#                   ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/PIL/Image.py", line 3476, in open
#     prefix = fp.read(16)
#              ^^^^^^^^^^^
# KeyboardInterrupt
# wandb:
# wandb: 🚀 View run young-dew-32 at: https://wandb.ai/ferranmartiol-gfdgfd/casalimpia/runs/gom17xko
# wandb: Find logs at: wandb/run-20250303_202416-gom17xko/logs

# %%
####with margin mask
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/casalimpia/back

# !python /content/casalimpia/back/main.py \
--empty-rooms-dir '/content/drive/My Drive/DATASETS/EmptyRooms/unique_unwatermarked' \
--masks-dir '/content/drive/My Drive/DATASETS/AutomaticallyGeneratedCoreMasks' \
--margin-masks-dir='/content/drive/My Drive/DATASETS/AutomaticallyGeneratedMarginMasks' \
--output-dir '/content/casalimpia/back/data' \
--model 'stability-ai' \
--epochs 500 \
--batch-size 20 \
--initial-learning-rate 4e-4 \
--img-size 512 \
--lora-rank 16 \
--lora-alpha 8 \
--lora-dropout 0.1 \
--lora-target-modules to_q to_v to_out.0 \
--img-size 512 \
--dtype 'float32' \
--save-latent-representations
# Out:
# Mounted at /content/drive
# /content/casalimpia/back
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2025-02-28 12:04:29.118666: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-28 12:04:29.139763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740744269.162736    2652 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740744269.169456    2652 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-28 12:04:29.192841: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.19.7
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# 2025-02-28 12:04:46 - INFO - Start training
# 2025-02-28 12:04:46 - INFO - Number of input images: 50
# 2025-02-28 12:04:47 - INFO - Number of masks: 10
# 2025-02-28 12:04:47 - INFO - Number of input images: 1
# 2025-02-28 12:04:47 - INFO - Number of masks: 1
# 2025-02-28 12:04:47 - INFO - Using device: cuda
# 2025-02-28 12:04:47 - INFO - Mixed precision: no
# model_index.json: 100% 544/544 [00:00<00:00, 1.98MB/s]
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/1.36G [00:00<?, ?B/s]
#
# text_encoder%2Fconfig.json: 100% 638/638 [00:00<00:00, 3.09MB/s]
#
#
# tokenizer%2Fspecial_tokens_map.json: 100% 460/460 [00:00<00:00, 2.77MB/s]
#
#
# (…)ure_extractor%2Fpreprocessor_config.json: 100% 342/342 [00:00<00:00, 1.60MB/s]
#
#
# scheduler%2Fscheduler_config.json: 100% 308/308 [00:00<00:00, 735kB/s]
#
#
# tokenizer%2Fvocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
# tokenizer%2Fmerges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
#
# tokenizer%2Ftokenizer_config.json: 100% 829/829 [00:00<00:00, 5.17MB/s]
#
#
#
#
# unet%2Fconfig.json: 100% 914/914 [00:00<00:00, 5.53MB/s]
#
# model.safetensors:   1% 10.5M/1.36G [00:00<00:15, 89.7MB/s]
#
#
#
# vae%2Fconfig.json:   0% 0.00/616 [00:00<?, ?B/s]
#
#
#
# vae%2Fconfig.json: 100% 616/616 [00:00<00:00, 624kB/s]
#
#
# tokenizer%2Fvocab.json: 100% 1.06M/1.06M [00:00<00:00, 5.71MB/s]
#
#
#
#
# tokenizer%2Fvocab.json: 100% 1.06M/1.06M [00:00<00:00, 5.63MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 10.5M/3.46G [00:00<00:37, 93.2MB/s]
# model.safetensors:   3% 41.9M/1.36G [00:00<00:07, 169MB/s]
#
#
# tokenizer%2Fmerges.txt: 100% 525k/525k [00:00<00:00, 1.56MB/s]
#
# model.safetensors:   5% 73.4M/1.36G [00:00<00:06, 208MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   1% 41.9M/3.46G [00:00<00:19, 174MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   3% 10.5M/335M [00:00<00:07, 43.6MB/s]
# model.safetensors:   8% 105M/1.36G [00:00<00:05, 229MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   2% 73.4M/3.46G [00:00<00:16, 205MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   9% 31.5M/335M [00:00<00:03, 90.6MB/s]
# model.safetensors:  10% 136M/1.36G [00:00<00:05, 238MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   3% 105M/3.46G [00:00<00:15, 222MB/s]
# model.safetensors:  12% 168M/1.36G [00:00<00:04, 244MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  16% 52.4M/335M [00:00<00:02, 113MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   4% 136M/3.46G [00:00<00:14, 230MB/s]
# model.safetensors:  15% 199M/1.36G [00:00<00:04, 246MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   5% 168M/3.46G [00:00<00:13, 239MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  22% 73.4M/335M [00:00<00:02, 124MB/s]
# model.safetensors:  17% 231M/1.36G [00:01<00:04, 245MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   6% 199M/3.46G [00:00<00:13, 240MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  28% 94.4M/335M [00:00<00:01, 132MB/s]
# model.safetensors:  19% 262M/1.36G [00:01<00:04, 246MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   7% 231M/3.46G [00:01<00:13, 242MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  34% 115M/335M [00:00<00:01, 136MB/s]
# model.safetensors:  22% 294M/1.36G [00:01<00:04, 242MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   8% 262M/3.46G [00:01<00:13, 243MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  41% 136M/335M [00:01<00:01, 138MB/s]
# model.safetensors:  24% 325M/1.36G [00:01<00:04, 246MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   8% 294M/3.46G [00:01<00:13, 243MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  47% 157M/335M [00:01<00:01, 141MB/s]
# model.safetensors:  26% 357M/1.36G [00:01<00:04, 242MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   9% 325M/3.46G [00:01<00:12, 247MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  53% 178M/335M [00:01<00:01, 142MB/s]
# model.safetensors:  28% 388M/1.36G [00:01<00:04, 242MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  10% 357M/3.46G [00:01<00:12, 244MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:01<00:00, 140MB/s]
# model.safetensors:  31% 419M/1.36G [00:01<00:03, 242MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  11% 388M/3.46G [00:01<00:12, 241MB/s]
# model.safetensors:  33% 451M/1.36G [00:01<00:03, 242MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  66% 220M/335M [00:01<00:00, 142MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  12% 419M/3.46G [00:01<00:12, 240MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  13% 451M/3.46G [00:01<00:12, 245MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  72% 241M/335M [00:01<00:00, 143MB/s]
# model.safetensors:  35% 482M/1.36G [00:02<00:03, 227MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  14% 482M/3.46G [00:02<00:12, 244MB/s]
# model.safetensors:  38% 514M/1.36G [00:02<00:03, 230MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  78% 262M/335M [00:01<00:00, 142MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  15% 514M/3.46G [00:02<00:12, 243MB/s]
# model.safetensors:  40% 545M/1.36G [00:02<00:03, 233MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  85% 283M/335M [00:02<00:00, 144MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  16% 545M/3.46G [00:02<00:11, 247MB/s]
# model.safetensors:  42% 577M/1.36G [00:02<00:03, 236MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:02<00:00, 144MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  17% 577M/3.46G [00:02<00:11, 248MB/s]
# model.safetensors:  45% 608M/1.36G [00:02<00:03, 230MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  97% 325M/335M [00:02<00:00, 144MB/s]
#
#
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 134MB/s]
#
# model.safetensors:  47% 640M/1.36G [00:02<00:03, 229MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  18% 640M/3.46G [00:02<00:11, 248MB/s]
# model.safetensors:  49% 671M/1.36G [00:02<00:03, 227MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  19% 671M/3.46G [00:02<00:11, 246MB/s]
# model.safetensors:  52% 703M/1.36G [00:03<00:02, 232MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  20% 703M/3.46G [00:02<00:11, 251MB/s]
# model.safetensors:  54% 734M/1.36G [00:03<00:02, 236MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  21% 734M/3.46G [00:03<00:10, 251MB/s]
# model.safetensors:  56% 765M/1.36G [00:03<00:02, 242MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  22% 765M/3.46G [00:03<00:10, 254MB/s]
# model.safetensors:  59% 797M/1.36G [00:03<00:02, 243MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  23% 797M/3.46G [00:03<00:10, 254MB/s]
# model.safetensors:  61% 828M/1.36G [00:03<00:02, 236MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  24% 828M/3.46G [00:03<00:10, 251MB/s]
# model.safetensors:  63% 860M/1.36G [00:03<00:02, 230MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  25% 860M/3.46G [00:03<00:10, 249MB/s]
# model.safetensors:  65% 891M/1.36G [00:03<00:02, 230MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  26% 891M/3.46G [00:03<00:10, 247MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  27% 923M/3.46G [00:03<00:10, 247MB/s]
# model.safetensors:  68% 923M/1.36G [00:03<00:01, 226MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  28% 954M/3.46G [00:03<00:10, 248MB/s]
# model.safetensors:  70% 954M/1.36G [00:04<00:01, 226MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  28% 986M/3.46G [00:04<00:10, 248MB/s]
# model.safetensors:  72% 986M/1.36G [00:04<00:01, 228MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  29% 1.02G/3.46G [00:04<00:09, 255MB/s]
# model.safetensors:  75% 1.02G/1.36G [00:04<00:01, 232MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  30% 1.05G/3.46G [00:04<00:09, 258MB/s]
# model.safetensors:  77% 1.05G/1.36G [00:04<00:01, 235MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  31% 1.08G/3.46G [00:04<00:09, 258MB/s]
# model.safetensors:  79% 1.08G/1.36G [00:04<00:01, 235MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  32% 1.11G/3.46G [00:04<00:09, 256MB/s]
# model.safetensors:  82% 1.11G/1.36G [00:04<00:01, 237MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  33% 1.14G/3.46G [00:04<00:09, 258MB/s]
# model.safetensors:  84% 1.14G/1.36G [00:04<00:00, 234MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  34% 1.17G/3.46G [00:04<00:09, 245MB/s]
# model.safetensors:  86% 1.17G/1.36G [00:05<00:00, 229MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  35% 1.21G/3.46G [00:04<00:09, 244MB/s]
# model.safetensors:  89% 1.21G/1.36G [00:05<00:00, 228MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  36% 1.24G/3.46G [00:05<00:09, 243MB/s]
# model.safetensors:  91% 1.24G/1.36G [00:05<00:00, 227MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  37% 1.27G/3.46G [00:05<00:09, 230MB/s]
# model.safetensors:  93% 1.27G/1.36G [00:05<00:00, 188MB/s]
# model.safetensors:  95% 1.30G/1.36G [00:05<00:00, 200MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:
B/s]
#
#
#
# diffusion_pytorch_model.safetensors:  93% 3.22G/3.46G [00:14<00:01, 210MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  94% 3.25G/3.46G [00:14<00:00, 216MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  95% 3.28G/3.46G [00:14<00:00, 224MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  96% 3.31G/3.46G [00:14<00:00, 231MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  97% 3.34G/3.46G [00:15<00:00, 232MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  97% 3.38G/3.46G [00:15<00:00, 182MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  98% 3.41G/3.46G [00:15<00:00, 197MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:  99% 3.44G/3.46G [00:15<00:00, 208MB/s]
#
#
#
# diffusion_pytorch_model.safetensors: 100% 3.46G/3.46G [00:15<00:00, 221MB/s]
# Fetching 13 files: 100% 13/13 [00:15<00:00,  1.22s/it]
# Loading pipeline components...: 100% 6/6 [00:00<00:00,  6.57it/s]
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 85.91it/s]
# 2025-02-28 12:05:07 - INFO - Epoch 1/500
# Epoch 1:   0% 0/4 [00:00<?, ?it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:05,  3.74it/s]
#  10% 2/20 [00:00<00:03,  5.82it/s]
#  15% 3/20 [00:00<00:02,  7.10it/s]
#  20% 4/20 [00:00<00:02,  7.90it/s]
#  25% 5/20 [00:00<00:01,  8.42it/s]
#  30% 6/20 [00:00<00:01,  8.78it/s]
#  35% 7/20 [00:00<00:01,  9.02it/s]
#  40% 8/20 [00:00<00:01,  9.19it/s]
#  45% 9/20 [00:01<00:01,  9.31it/s]
#  50% 10/20 [00:01<00:01,  9.38it/s]
#  55% 11/20 [00:01<00:00,  9.44it/s]
#  60% 12/20 [00:01<00:00,  9.48it/s]
#  65% 13/20 [00:01<00:00,  9.49it/s]
#  70% 14/20 [00:01<00:00,  9.50it/s]
#  75% 15/20 [00:01<00:00,  9.49it/s]
#  80% 16/20 [00:01<00:00,  9.50it/s]
#  85% 17/20 [00:01<00:00,  9.52it/s]
#  90% 18/20 [00:02<00:00,  9.53it/s]
#  95% 19/20 [00:02<00:00,  9.54it/s]
# 100% 20/20 [00:02<00:00,  8.86it/s]
# 2025-02-28 12:05:34 - INFO - Initial PSNR: 12.968512535095215
# 2025-02-28 12:05:34 - INFO - Batch loss: 0.08550915867090225
# Epoch 1:  25% 1/4 [00:28<01:24, 28.20s/it]Traceback (most recent call last):
#   File "/content/casalimpia/back/main.py", line 587, in <module>
#     main()
#   File "/content/casalimpia/back/main.py", line 558, in main
#     train_lora(model_id,
#   File "/content/casalimpia/back/main.py", line 266, in train_lora
#     for step, (input_images, input_masks, targets, unpadded_masks) in enumerate(train_loader):
#   File "/usr/local/lib/python3.11/dist-packages/accelerate/data_loader.py", line 574, in __iter__
#     next_batch = next(dataloader_iter)
#                  ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 701, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 757, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py", line 50, in fetch
#     data = self.dataset.__getitems__(possibly_batched_index)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataset.py", line 420, in __getitems__
#     return [self.dataset[self.indices[idx]] for idx in indices]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataset.py", line 420, in <listcomp>
#     return [self.dataset[self.indices[idx]] for idx in indices]
#             ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/content/casalimpia/back/empty_rooms_dataset.py", line 36, in __getitem__
#     input_image = cv2.imread(input_path)
#                   ^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/casalimpia/back/wandb/offline-run-20250228_120445-x8lwsnpx
# wandb: Find logs at: wandb/offline-run-20250228_120445-x8lwsnpx/logs

# %%
####with margin + gradient accumulation + accelerate
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/casalimpia/back

# !python /content/casalimpia/back/main.py \
--empty-rooms-dir '/content/drive/My Drive/DATASETS/EmptyRooms/unique_unwatermarked' \
--masks-dir '/content/drive/My Drive/DATASETS/AutomaticallyGeneratedCoreMasks' \
--margin-masks-dir='/content/drive/My Drive/DATASETS/AutomaticallyGeneratedMarginMasks' \
--output-dir '/content/casalimpia/back/data' \
--model 'stability-ai' \
--epochs 10 \
--batch-size 10 \
--initial-learning-rate 4e-4 \
--gradient-accumulation-steps 5 \
--img-size 512 \
--lora-rank 16 \
--lora-alpha 8 \
--lora-target-modules to_k to_q to_v to_out.0 \
--lora-dropout 0.1 \
--dtype 'float32' \
--save-latent-representations
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  40% 4/10 [00:04<00:06,  1.13s/it]
#  50% 5/10 [00:05<00:05,  1.08s/it]
#  60% 6/10 [00:06<00:04,  1.05s/it]
#  70% 7/10 [00:07<00:03,  1.03s/it]
#  80% 8/10 [00:08<00:02,  1.02s/it]
#  90% 9/10 [00:09<00:01,  1.01s/it]
# 100% 10/10 [00:10<00:00,  1.09s/it]
# 2025-03-02 01:03:46 - INFO - Batch 160 PSNR: 16.23782730102539
# 2025-03-02 01:03:47 - INFO - Batch loss: 0.06493721157312393
# Epoch 7:  18% 162/902 [04:54<1:20:53,  6.56s/it]2025-03-02 01:03:49 - INFO - Batch loss: 0.05156615003943443
# Epoch 7:  18% 163/902 [04:55<1:01:34,  5.00s/it]2025-03-02 01:03:50 - INFO - Batch loss: 0.0577072873711586
# Epoch 7:  18% 164/902 [04:56<48:03,  3.91s/it]  2025-03-02 01:03:51 - INFO - Batch loss: 0.033477868884801865
# Epoch 7:  18% 165/902 [04:58<38:36,  3.14s/it]2025-03-02 01:03:53 - INFO - Batch loss: 0.0750812217593193
# Epoch 7:  18% 166/902 [04:59<31:59,  2.61s/it]2025-03-02 01:03:54 - INFO - Batch loss: 0.05901671200990677
# Epoch 7:  19% 167/902 [05:00<27:25,  2.24s/it]2025-03-02 01:03:56 - INFO - Batch loss: 0.04070819541811943
# Epoch 7:  19% 168/902 [05:02<24:09,  1.97s/it]2025-03-02 01:03:57 - INFO - Batch loss: 0.017814278602600098
# Epoch 7:  19% 169/902 [05:03<21:52,  1.79s/it]2025-03-02 01:03:58 - INFO - Batch loss: 0.05107366666197777
# Epoch 7:  19% 170/902 [05:04<20:16,  1.66s/it]2025-03-02 01:04:00 - INFO - Batch loss: 0.04096861928701401
# Epoch 7:  19% 171/902 [05:06<19:08,  1.57s/it]2025-03-02 01:04:00 - INFO - GPU Memory - Allocated: 5.03GB, Reserved: 6.28GB
# 2025-03-02 01:04:01 - INFO - Batch loss: 0.08869953453540802
# Epoch 7:  19% 172/902 [05:07<18:25,  1.51s/it]2025-03-02 01:04:02 - INFO - Batch loss: 0.030243951827287674
# Epoch 7:  19% 173/902 [05:09<17:50,  1.47s/it]2025-03-02 01:04:04 - INFO - Batch loss: 0.04312491789460182
# Epoch 7:  19% 174/902 [05:10<17:25,  1.44s/it]2025-03-02 01:04:05 - INFO - Batch loss: 0.07968565076589584
# Epoch 7:  19% 175/902 [05:11<17:07,  1.41s/it]2025-03-02 01:04:06 - INFO - Batch loss: 0.04553021118044853
# Epoch 7:  20% 176/902 [05:13<16:54,  1.40s/it]2025-03-02 01:04:08 - INFO - Batch loss: 0.03312118351459503
# Epoch 7:  20% 177/902 [05:14<16:48,  1.39s/it]2025-03-02 01:04:09 - INFO - Batch loss: 0.04362377151846886
# Epoch 7:  20% 178/902 [05:15<16:40,  1.38s/it]2025-03-02 01:04:11 - INFO - Batch loss: 0.10311229526996613
# Epoch 7:  20% 179/902 [05:17<16:34,  1.38s/it]2025-03-02 01:04:12 - INFO - Batch loss: 0.023247921839356422
# Epoch 7:  20% 180/902 [05:18<16:29,  1.37s/it]2025-03-02 01:04:13 - INFO - Batch loss: 0.05223310738801956
# Epoch 7:  20% 181/902 [05:19<16:24,  1.37s/it]2025-03-02 01:04:14 - INFO - GPU Memory - Allocated: 5.03GB, Reserved: 6.28GB
# 2025-03-02 01
- INFO - GPU Memory - Allocated: 5.03GB, Reserved: 6.28GB
# 2025-03-02 02:46:52 - INFO - Batch loss: 0.0193006731569767
# Epoch 10:  99% 892/902 [26:57<00:15,  1.52s/it]2025-03-02 02:46:53 - INFO - Batch loss: 0.03887087479233742
# Epoch 10:  99% 893/902 [26:58<00:13,  1.47s/it]2025-03-02 02:46:55 - INFO - Batch loss: 0.05285797268152237
# Epoch 10:  99% 894/902 [26:59<00:11,  1.44s/it]2025-03-02 02:46:56 - INFO - Batch loss: 0.05428581312298775
# Epoch 10:  99% 895/902 [27:01<00:09,  1.41s/it]2025-03-02 02:46:57 - INFO - Batch loss: 0.03912489116191864
# Epoch 10:  99% 896/902 [27:02<00:08,  1.40s/it]2025-03-02 02:46:59 - INFO - Batch loss: 0.07511943578720093
# Epoch 10:  99% 897/902 [27:04<00:06,  1.40s/it]2025-03-02 02:47:00 - INFO - Batch loss: 0.02670830860733986
# Epoch 10: 100% 898/902 [27:05<00:05,  1.38s/it]2025-03-02 02:47:01 - INFO - Batch loss: 0.05938735604286194
# Epoch 10: 100% 899/902 [27:06<00:04,  1.38s/it]2025-03-02 02:47:03 - INFO - Batch loss: 0.016148224472999573
# Epoch 10: 100% 900/902 [27:08<00:02,  1.37s/it]2025-03-02 02:47:04 - INFO - Batch loss: 0.016191234812140465
# Epoch 10: 100% 901/902 [27:09<00:01,  1.37s/it]2025-03-02 02:47:05 - INFO - GPU Memory - Allocated: 5.03GB, Reserved: 6.28GB
# 2025-03-02 02:47:05 - INFO - Batch loss: 0.060098711401224136
# Epoch 10: 100% 902/902 [27:10<00:00,  1.81s/it]
# 2025-03-02 02:47:06 - INFO - Epoch 9 Loss: 0.0627839830301355
# 2025-03-02 02:47:06 - INFO - Training complete. Saving LoRA weights...
# /usr/local/lib/python3.11/dist-packages/diffusers/loaders/unet.py:473: FutureWarning: `save_attn_procs` is deprecated and will be removed in version 0.40.0. Using the `save_attn_procs()` method has been deprecated and will be removed in a future version. Please use `save_lora_adapter()`.
#   deprecate("save_attn_procs", "0.40.0", deprecation_message)
# 2025-03-02 02:47:06 - INFO - Training completed. Initial timestamp: 20250301_220714.
# 2025-03-02 02:47:06 - INFO - Final timestamp: 20250302_024706.
# 2025-03-02 02:47:06 - INFO - Elapsed time in seconds: 16791.474595.
# 2025-03-02 02:47:06 - INFO - End training
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/casalimpia/back/wandb/offline-run-20250301_220719-dt1rf5yj
# wandb: Find logs at: wandb/offline-run-20250301_220719-dt1rf5yj/logs

# %%
####with margin + gradient accumulation + accelerate + prodigy
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/casalimpia/back

# !python /content/casalimpia/back/main.py \
--empty-rooms-dir '/content/drive/My Drive/DATASETS/EmptyRooms/unique_unwatermarked' \
--masks-dir '/content/drive/My Drive/DATASETS/AutomaticallyGeneratedCoreMasks' \
--margin-masks-dir='/content/drive/My Drive/DATASETS/AutomaticallyGeneratedMarginMasks' \
--output-dir '/content/casalimpia/back/data' \
--model 'stability-ai' \
--epochs 15 \
--batch-size 15 \
--initial-learning-rate 1.0 \
--gradient-accumulation-steps 5 \
--img-size 512 \
--lora-rank 32\
--lora-alpha 64 \
--lora-target-modules to_k to_q to_v to_out.0 \
--lora-dropout 0.1 \
--dtype 'float32' \
--save-latent-representations
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/casalimpia/back
# 2025-03-18 09:08:17.459482: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742288897.486328    5695 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742288897.494975    5695 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-18 09:08:17.539464: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ferranmartiol (ferranmartiol-gfdgfd) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.8
# wandb: Run data is saved locally in /content/casalimpia/back/wandb/run-20250318_090823-fc8izuqw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dark-dust-77
# wandb: ⭐️ View project at https://wandb.ai/ferranmartiol-gfdgfd/casalimpia
# wandb: 🚀 View run at https://wandb.ai/ferranmartiol-gfdgfd/casalimpia/runs/fc8izuqw
# 2025-03-18 09:08:24 - INFO - Start training
# 2025-03-18 09:08:26 - INFO - Number of input images: 12882
# 2025-03-18 09:08:26 - INFO - Number of masks: 323
# 2025-03-18 09:08:26 - INFO - Number of input images: 1
# 2025-03-18 09:08:26 - INFO - Number of masks: 1
# 2025-03-18 09:08:26 - INFO - Using device: cuda
# 2025-03-18 09:08:26 - INFO - Mixed precision: no
# Loading pipeline components...: 100% 6/6 [00:00<00:00,  8.18it/s]
# Using decoupled weight decay
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 71.55it/s]
# 2025-03-18 09:08:45 - INFO - Pre-encoding all prompts...
# 2025-03-18 09:08:46 - INFO - Encoded 20 prompts
# 2025-03-18 09:08:46 - INFO - Epoch 1/15
# Epoch 1:   0% 0/602 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/content/casalimpia/back/main.py", line 615, in <module>
#     main()
#   File "/content/casalimpia/back/main.py", line 585, in main
#     train_lora(model_id,
#   File "/content/casalimpia/back/main.py", line 300, in train_lora
#     masked_latents = vae.encode(masked_images).latent_dist.sample() * vae.config.scaling_factor
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/diffusers/utils/accelerate_utils.py", line 46, in wrapper
#     return method(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/diffusers/models/autoencoders/autoencoder_kl.py", line 282, in encode
#     h = self._encode(x)
#         ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/diffusers/models/autoencoders/autoencoder_kl.py", line 256, in _encode
#     enc = self.encoder(x)
#           ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/diffusers/models/autoencoders/vae.py", line 185, in forward
#     sample = down_block(sample)
#              ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/diffusers/models/unets/unet_2d_blocks.py", line 1520, in forward
#     hidden_states = resnet(hidden_states, temb=None)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/diffusers/models/resnet.py", line 371, in forward
#     output_tensor = (input_tensor + hidden_states) / self.output_scale_factor
#                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 1.88 GiB. GPU 0 has a total capacity of 14.74 GiB of which 1.30 GiB is free. Process 64105 has 13.44 GiB memory in use. Of the allocated memory 12.47 GiB is allocated by PyTorch, and 867.03 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# wandb:
# wandb: 🚀 View run dark-dust-77 at: https://wandb.ai/ferranmartiol-gfdgfd/casalimpia/runs/fc8izuqw
# wandb: Find logs at: wandb/run-20250318_090823-fc8izuqw/logs

# %%
from google.colab import files
import shutil

# Specify the full path to your folder
folder_path = '/content/casalimpia/back/data/lora_trains'

# Create a ZIP archive with the same name as the last folder in the path
folder_name = folder_path.split('/')[-1]  # This gets 'lora_trains'
zip_name = f'{folder_name}_backup'

# Create the ZIP archive from your folder
shutil.make_archive(zip_name, 'zip', folder_path)

# Initiate the download
files.download(f'{zip_name}.zip')

# %%
import os
from google.colab import drive
import cv2
import numpy as np
from tqdm import tqdm
import re

def mount_drive():
    """Mount Google Drive."""
    drive.mount('/content/drive')

def extract_number_from_filename(filename):
    """Extract the number from the mask filename."""
    match = re.match(r'(\d+)_', filename)
    if match:
        return match.group(1)
    return None

def load_images_from_folder(folder_path):
    """Load all images from a folder."""
    images = []
    filenames = []
    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith('.png'):
            img_path = os.path.join(folder_path, filename)
            # Read PNG with alpha channel
            img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
            if img is not None:
                images.append(img)
                filenames.append(filename)
        elif filename.lower().endswith(('.jpg', '.jpeg')):
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            if img is not None:
                images.append(img)
                filenames.append(filename)
    return images, filenames

def merge_images(room, contour):
    """Overlay contour on room after resizing, using only visible contour pixels."""
    # Resize contour to match room dimensions
    contour_resized = cv2.resize(contour, (room.shape[1], room.shape[0]))

    # Create output image starting with room
    result = room.copy()

    if contour_resized.shape[2] == 4:  # If image has alpha channel
        # Create mask from alpha channel
        alpha = contour_resized[:, :, 3]
        # Only consider pixels with significant alpha values (visible pixels)
        visible_mask = alpha > 10  # Threshold can be adjusted

        # Copy the RGB channels where the mask is visible
        result[visible_mask] = contour_resized[:, :, :3][visible_mask]
    else:
        # If no alpha channel, use intensity to determine contour pixels
        gray = cv2.cvtColor(contour_resized, cv2.COLOR_BGR2GRAY)
        visible_mask = gray > 10  # Threshold can be adjusted
        result[visible_mask] = contour_resized[visible_mask]

    return result

def process_images(rooms_folder, masks_folder, output_folder):
    """Process all images in the folders."""
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Load images
    rooms, room_filenames = load_images_from_folder(rooms_folder)
    masks, mask_filenames = load_images_from_folder(masks_folder)

    print(f"Found {len(rooms)} room images and {len(masks)} mask images")

    # Process each pair
    for i in tqdm(range(min(len(rooms), len(masks)))):
        room = rooms[i]
        contour = masks[i]
        mask_filename = mask_filenames[i]

        # Extract number from mask filename
        number = extract_number_from_filename(mask_filename)
        if number is None:
            print(f"Warning: Could not extract number from filename {mask_filename}")
            output_filename = f"merged_{i}.jpg"
        else:
            output_filename = f"{number}_merged.jpg"

        # Merge images
        merged = merge_images(room, contour)

        # Save result
        output_path = os.path.join(output_folder, output_filename)
        cv2.imwrite(output_path, merged)
        print(f"Saved: {output_filename}")

        # Also save the mask we're actually using (for verification)
        if contour.shape[2] == 4:
            mask_vis = (contour[:,:,3] > 10).astype(np.uint8) * 255
        else:
            mask_vis = cv2.cvtColor(contour, cv2.COLOR_BGR2GRAY)
        cv2.imwrite(os.path.join(output_folder, f"{number}_mask_used.jpg"), mask_vis)

def main():
    # Mount Google Drive
    mount_drive()

    # Define paths
    base_path = '/content/drive/MyDrive/DATASETS'
    rooms_folder = os.path.join(base_path, 'sampleEmptyRooms')
    masks_folder = os.path.join(base_path, 'sampleMarginMasks')
    output_folder = os.path.join(base_path, 'sampleMerged')

    # Process images
    process_images(rooms_folder, masks_folder, output_folder)
    print("Processing complete! Check the sampleMerged folder for results.")

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 50 room images and 50 mask images
#   4%|▍         | 2/50 [00:00<00:02, 17.96it/s]
# Saved: 1299846779_merged.jpg
# Saved: 1299846829_merged.jpg
# Saved: 1299856041_merged.jpg
# Saved: 1299873811_merged.jpg
#  10%|█         | 5/50 [00:00<00:01, 23.52it/s]
# Saved: 1299873850_merged.jpg
#  16%|█▌        | 8/50 [00:00<00:01, 22.30it/s]
# Saved: 1299873931_merged.jpg
# Saved: 1299873954_merged.jpg
# Saved: 1299874320_merged.jpg
# Saved: 1299879829_merged.jpg
# Saved: 1299913325_merged.jpg
#  22%|██▏       | 11/50 [00:00<00:01, 21.21it/s]
# Saved: 1299913368_merged.jpg
# Saved: 1299913449_merged.jpg
# Saved: 1299913469_merged.jpg
#  28%|██▊       | 14/50 [00:00<00:01, 20.63it/s]
# Saved: 1299913504_merged.jpg
#  34%|███▍      | 17/50 [00:00<00:01, 20.27it/s]
# Saved: 1299918059_merged.jpg
# Saved: 1299939175_merged.jpg
# Saved: 1299939179_merged.jpg
# Saved: 1299945688_merged.jpg
#  40%|████      | 20/50 [00:00<00:01, 20.30it/s]
# Saved: 1299945690_merged.jpg
# Saved: 1299949295_merged.jpg
# Saved: 1299952656_merged.jpg
# Saved: 1299953937_merged.jpg
#  50%|█████     | 25/50 [00:01<00:01, 18.68it/s]
# Saved: 1299953939_merged.jpg
# Saved: 1299953974_merged.jpg
# Saved: 1299953995_merged.jpg
# Saved: 1299960017_merged.jpg
# Saved: 1299961850_merged.jpg
#  56%|█████▌    | 28/50 [00:01<00:01, 19.93it/s]
# Saved: 1299963326_merged.jpg
# Saved: 1299963327_merged.jpg
# Saved: 1299963348_merged.jpg
#  62%|██████▏   | 31/50 [00:01<00:00, 20.29it/s]
# Saved: 1299963911_merged.jpg
# Saved: 1299975329_merged.jpg
#  68%|██████▊   | 34/50 [00:01<00:00, 20.46it/s]
# Saved: 1299975353_merged.jpg
# Saved: 1299980577_merged.jpg
# Saved: 1299998591_merged.jpg
#  74%|███████▍  | 37/50 [00:01<00:00, 21.39it/s]
# Saved: 1299999270_merged.jpg
# Saved: 1299999327_merged.jpg
#  80%|████████  | 40/50 [00:01<00:00, 21.04it/s]
# Saved: 1299999328_merged.jpg
# Saved: 1299999428_merged.jpg
# Saved: 1299999434_merged.jpg
# Saved: 595043039_merged.jpg
#  86%|████████▌ | 43/50 [00:02<00:00, 20.43it/s]
# Saved: 700125260_merged.jpg
# Saved: 773740891_merged.jpg
# Saved: 773740909_merged.jpg
# Saved: 773740910_merged.jpg
#  96%|█████████▌| 48/50 [00:02<00:00, 17.65it/s]
# Saved: 773810658_merged.jpg
# Saved: 903254896_merged.jpg
# Saved: 903254897_merged.jpg
# Saved: 905212034_merged.jpg
# 100%|██████████| 50/50 [00:02<00:00, 19.77it/s]
# Saved: 905212054_merged.jpg
# Processing complete! Check the sampleMerged folder for results.

# %%
import shutil
from google.colab import files

# Define folder path and zip file name
folder_path = "/content/casalimpia/back/blending_visualizations"
zip_path = "/content/blending_visualizations.zip"

# Zip the folder
shutil.make_archive(zip_path.replace(".zip", ""), 'zip', folder_path)

# Download the zip file
files.download(zip_path)
